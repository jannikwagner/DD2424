# %%
using DifferentialEquations, Plots, DelimitedFiles, Flux, DiffEqSensitivity

# %%
#]add ChainRulesCore@1

# %%
# Define ODE
function EpMod(x, p, t)
    s, e, i, r = x
    γ, R₀, σ = p
    return [-γ*R₀*s*i;       # ds/dt = -γR₀si
             γ*R₀*s*i -  σ*e;# de/dt =  γR₀si -σe
             σ*e - γ*i;      # di/dt =         σe -γi
                   γ*i;      # dr/dt =             γi
            ]
end

N = 10^7
i_0 = 1E-7                  # 33 = 1E-7 * 330 million population = initially infected
e_0 = 4.0 * i_0             # 132 = 1E-7 *330 million = initially exposed
s_0 = 1.0 - i_0 - e_0
r_0 = 0.0
x_0 = [s_0, e_0, i_0, r_0]  # initial condition
γ = 1/5
R₀ = 3.0
σ = 1/5.2 # parameters
p_0 = [γ,R₀,σ]


dat = readdlm("covid.txt",',');
time_i = dat[:,1]; # times
Infected = 50*dat[:,2]/N; # Normalize data
Infected[2:end] = Infected[2:end] 
#scatter(time_i,Infected,label="Infected")


# Solve the problem with an ODE solver
tspan = (0.0, maximum(time_i))  # ≈ 170 days
prob = ODEProblem(EpMod, x_0, tspan, p_0)
sol = solve(prob, Tsit5())
sol2 = solve(prob,Tsit5(),saveat=0.1)
# plot the solution
plot(sol, labels = ["s" "e" "i" "r"], title = "SEIR Dynamics", lw = 2, xlabel = "t")
tshort_inds = (Int.(time_i)*10).+1
tshort = Int.(time_i).+1
A = sol2[3,tshort_inds] # length 101 vector
A = A + randn(length(tshort))/1000
A = Infected;
scatter!(tshort,A)

# Initial guess
p = [0.17,5.7,0.170]
params = Flux.params(p)

# Prediction function
function predict_rd() # Our 1-layer "neural network"
  solve(prob,Tsit5(),p=p,saveat=0.1,maxiters=1e7)[3,:] # override with new parameters
end

# loss function: MSE
loss_rd() = sum(abs2,predict_rd()[tshort_inds] .-  A) 

# Perform training
data = Iterators.repeated((), 200)
opt = ADAM()
cb = function () #callback function to observe training
  display(loss_rd())
  # using `remake` to re-create our `prob` with current parameters `p`
  #display(plot(solve(remake(prob,p=p),Tsit5(),saveat=0.1),ylim=(0,10)))
  #cur_pred = predict_rd()
  #pl = scatter(tshort,A,label="Data",yticks = ([0:0.05:0.25;], ["0", "10000", "20000", "30000", "40000", "50000", "60000"]))
  #plot!(pl,solve(remake(prob,p=p),Tsit5(),saveat=0.1,maxiters=1e7),vars=(3),ylim=(0,0.25), labels = "ODE approximation (SEIR)", legend=:topright, dpi=500, color="blue")
  #scatter!(pl,t,cur_pred[1,:],label="prediction")
  #display(plot(pl))
end

# Display the ODE with the initial parameter values.
cb()
# Out:
# 0.29616427937098294

# %%
Flux.train!(loss_rd, params, data, opt, cb = cb)
# Out:
# No adjoint rules exist. Check that you added `using DiffEqSensitivity`
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:33
#   [2] _concrete_solve_adjoint(::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, ::Vararg{Any, N} where N; kwargs::Base.Iterators.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:saveat, :maxiters), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/S7V8q/src/solve.jl:562
#   [3] _solve_adjoint(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Vector{Float64}, args::Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}; merge_callbacks::Bool, kwargs::Base.Iterators.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:saveat, :maxiters), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/S7V8q/src/solve.jl:526
#   [4] rrule(::typeof(DiffEqBase.solve_up), prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Vector{Float64}, args::Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}; kwargs::Base.Iterators.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:saveat, :maxiters), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/S7V8q/src/solve.jl:489
#   [5] chain_rrule_kw
#     @ ~/.julia/packages/Zygote/ytjqm/src/compiler/chainrules.jl:229 [inlined]
#   [6] macro expansion
#     @ ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0 [inlined]
#   [7] _pullback(::Zygote.Context, ::DiffEqBase.var"#solve_up##kw", ::NamedTuple{(:saveat, :maxiters), Tuple{Float64, Float64}}, ::typeof(DiffEqBase.solve_up), ::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, ::Nothing, ::Vector{Float64}, ::Vector{Float64}, ::Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:9
#   [8] _apply(::Function, ::Vararg{Any, N} where N)
#     @ Core ./boot.jl:804
#   [9] adjoint
#     @ ~/.julia/packages/Zygote/ytjqm/src/lib/lib.jl:200 [inlined]
#  [10] _pullback
#     @ ~/.julia/packages/ZygoteRules/AIbCs/src/adjoint.jl:65 [inlined]
#  [11] _pullback
#     @ ~/.julia/packages/DiffEqBase/S7V8q/src/solve.jl:234 [inlined]
#  [12] _pullback(::Zygote.Context, ::DiffEqBase.var"##solve#40", ::Nothing, ::Nothing, ::Vector{Float64}, ::KeywordArgError, ::Base.Iterators.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:saveat, :maxiters), Tuple{Float64, Float64}}}, ::typeof(solve), ::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, ::Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0
#  [13] _apply(::Function, ::Vararg{Any, N} where N)
#     @ Core ./boot.jl:804
#  [14] adjoint
#     @ ~/.julia/packages/Zygote/ytjqm/src/lib/lib.jl:200 [inlined]
#  [15] _pullback
#     @ ~/.julia/packages/ZygoteRules/AIbCs/src/adjoint.jl:65 [inlined]
#  [16] _pullback
#     @ ~/.julia/packages/DiffEqBase/S7V8q/src/solve.jl:228 [inlined]
#  [17] _pullback(::Zygote.Context, ::CommonSolve.var"#solve##kw", ::NamedTuple{(:p, :saveat, :maxiters), Tuple{Vector{Float64}, Float64, Float64}}, ::typeof(solve), ::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float64}, ODEFunction{false, typeof(EpMod), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing}, Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, ::Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0
#  [18] _pullback
#     @ ./In[5]:51 [inlined]
#  [19] _pullback(::Zygote.Context, ::typeof(predict_rd))
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0
#  [20] _pullback
#     @ ./In[5]:55 [inlined]
#  [21] _pullback(::Zygote.Context, ::typeof(loss_rd))
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0
#  [22] _apply
#     @ ./boot.jl:804 [inlined]
#  [23] adjoint
#     @ ~/.julia/packages/Zygote/ytjqm/src/lib/lib.jl:200 [inlined]
#  [24] _pullback
#     @ ~/.julia/packages/ZygoteRules/AIbCs/src/adjoint.jl:65 [inlined]
#  [25] _pullback
#     @ ~/.julia/packages/Flux/qAdFM/src/optimise/train.jl:110 [inlined]
#  [26] _pullback(::Zygote.Context, ::Flux.Optimise.var"#39#45"{typeof(loss_rd), Tuple{}})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface2.jl:0
#  [27] pullback(f::Function, ps::Zygote.Params{Zygote.Buffer{Any, Vector{Any}}})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface.jl:352
#  [28] gradient(f::Function, args::Zygote.Params{Zygote.Buffer{Any, Vector{Any}}})
#     @ Zygote ~/.julia/packages/Zygote/ytjqm/src/compiler/interface.jl:75
#  [29] macro expansion
#     @ ~/.julia/packages/Flux/qAdFM/src/optimise/train.jl:109 [inlined]
#  [30] macro expansion
#     @ ~/.julia/packages/Juno/n6wyj/src/progress.jl:134 [inlined]
#  [31] train!(loss::Function, ps::Zygote.Params{Zygote.Buffer{Any, Vector{Any}}}, data::Base.Iterators.Take{Base.Iterators.Repeated{Tuple{}}}, opt::ADAM; cb::var"#1#2")
#     @ Flux.Optimise ~/.julia/packages/Flux/qAdFM/src/optimise/train.jl:107
#  [32] top-level scope
#     @ In[6]:1
#  [33] eval
#     @ ./boot.jl:360 [inlined]
#  [34] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094
